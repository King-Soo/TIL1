# %%
import urllib. request as req
from bs4 import BeautifulSoup

# %%
url="http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp"
res=req.urlopen(url)
BeautifulSoup(res,"html.parser")
# BeautifulSoup은 html, xml 문서를 분석하는 도구
# Out:
# <?xml version="1.0" encoding="utf-8" ?>
# <rss version="2.0">
# <channel>
# <title>기상청 육상 중기예보</title>
# <link/>http://www.kma.go.kr/weather/forecast/mid-term_01.jsp
# <description>기상청 날씨 웹서비스</description>
# <language>ko</language>
# <generator>기상청</generator>
# <pubdate>2021년 07월 20일 (화)요일 06:00</pubdate>
# <item>
# <author>기상청</author>
# <category>육상중기예보</category>
# <title>전국 육상 중기예보 - 2021년 07월 20일 (화)요일 06:00 발표</title>
# <link/>http://www.kma.go.kr/weather/forecast/mid-term_01.jsp
# <guid>http://www.kma.go.kr/weather/forecast/mid-term_01.jsp</guid>
# <description>
# <header>
# <title>전국 육상중기예보</title>
# <tm>202107200600</tm>
# ...

# %%
html="""
<html>
<body>
<h1>스크레핑</h1>
<p>웹 페이지 분석</p>
<p>원하는 부분 추출</p>
</body>
</html>
"""

soup=BeautifulSoup(html,'html.parser')
soup.find("h1")
soup.html.body.p
soup.p
#soup.find_allnd("p")[1].string
# Out:
# <p>웹 페이지 분석</p>

# %%
sib1=soup.html.body.h1
sib1

# %%
sib1.next_sibling

# %%
sib2=soup.html.body.p
sib2

# %%
sib2.next_sibling.next_sibling

# %%
html="""<html><body><h1>스크레핑</h1><p>웹 페이지 분석</p><p>원하는 부분 추출</p></body></html>"""
soup=BeautifulSoup(html,'html.parser')

# %%
html3="""
<html><body>
<ul>
<li><a href="http://www.naver.com">naver</a></li>
<li><a href="http://www.daum.net">daum</a></li>
</ul>
</body></html>
"""

soup=BeautifulSoup(html3,'html.parser')
soup.find("a")
links=soup.find_all("a")
for i in links:
    print(i.attrs.values())
# Out:
# dict_values(['http://www.naver.com'])
# dict_values(['http://www.daum.net'])

# %%
html4="""
<p><a href="aaa.html" name="kkk">aaa page</a></p>
"""
soup4=BeautifulSoup(html4,'html.parser')
aa=soup4.find_all("a")
for i in aa:
    print(i.attrs)
# Out:
# {'href': 'aaa.html', 'name': 'kkk'}

# %%
url3="http://www.weather.go.kr/weather/forecast/mid-term-rss3.jsp"
res2=req.urlopen(url3)
soup5=BeautifulSoup(res2,'html.parser')
tmn=soup5.find_all("tmn")
#len(tmn)
for tmn in tmn:
    print(tmn.text)
# Out:
# 26
# 26
# 26
# 26
# 26
# 26
# 25
# 25
# 24
# 24
# 25
# 25
# 25
# 26
# 26
# 26
# 26
# 26
# 26
# 26
# 26
# 24
# 24
# 24
# 24
# 24
# 25
# 25
# 25
# 25
# 25
# 25
# 25
# 25
# 24
# 24
# 24
# 25
# 24
# 23
# 23
# 24
# 24
# 24
# 24
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 22
# 22
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 23
# 23
# 23
# 23
# 23
# 24
# 24
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 23
# 23
# 23
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 23
# 23
# 24
# 24
# 24
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 24
# 24
# 24
# 24
# 25
# 25
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 22
# 22
# 23
# 23
# 24
# 24
# 23
# 23
# 23
# 23
# 22
# 23
# 23
# 22
# 22
# 23
# 23
# 24
# 24
# 22
# 22
# 22
# 22
# 22
# 23
# 23
# 25
# 25
# 25
# 25
# 25
# ...

# %%
from bs4 import BeautifulSoup

html4 = """
<html><body>
<div id="lang">
    <h1>programming</h1>
    <ul class="items">
        <li>python</li>
        <li>java</li>
        <li>cpp</li>
    </ul>
</div>
</body></html>
"""

# %%
soup=BeautifulSoup(html4,'html.parser')

# %%
soup.h1.string
# Out:
# 'programming'

# %%
soup.select('div') # select: findall 처럼 div 태그를 모두 찾아냄(list)
soup.select_one('div') # select_one: find처럼 맨 처음 만나게 되는 div 태그 영역을
# Out:
# <div id="lang">
# <h1>programming</h1>
# <ul class="items">
# <li>python</li>
# <li>java</li>
# <li>cpp</li>
# </ul>
# </div>

# %%
soup.find('div') #find : 맨 처음 만나게 되는 div 태그 영역을 추출
# Out:
# <div id="lang">
# <h1>programming</h1>
# <ul class="items">
# <li>python</li>
# <li>java</li>
# <li>cpp</li>
# </ul>
# </div>

# %%
from bs4 import BeautifulSoup

html5 = """
<html><body>
<div id="lang">
    <h1>programming</h1>
    <ul class="items">
        <li>python</li>
        <li>java</li>
        <li>cpp</li>
    </ul>
</div>
</body></html>
"""

# %%
soup=BeautifulSoup(html5,'html.parser')
#soup.select("div#lang") # #=id를 뜻함

soup.select("div#lang")[0]
soup.select("div#lang>ul>li")[1].string
# Out:
# 'java'

# %%
from bs4 import BeautifulSoup 
import re # 정규 표현식을 사용할 때 --- (※1)
html = """
<ul>
  <li><a href="hoge.html">hoge</li>
  <li><a href="https://example.com/fuga">fuga*</li>
  <li><a href="https://example.com/foo">foo*</li>
  <li><a href="http://example.com/aaa">aaa</li>
</ul>
"""

# %%
soup=BeautifulSoup(html,'html.parser')
[sel.string for sel in soup.select("ul>li>a")]
# Out:
# ['hoge', 'fuga*', 'foo*', 'aaa']

# %%
res = soup.select('li > a')
addr=[ i.attrs['href'] for i in res]


import re
for i in range(len(addr)):
    res=re.match("https",addr[i])
    if res:
        print(addr[i])

        
li=soup.find_all(href=re.compile('^https'))
# Out:
# https://example.com/fuga
# https://example.com/foo

# %%
# url:"ttps://ko.wikisource.org/wiki/%EC%A0%80%EC%9E%90:%EC%9C%A4%EB%8F%99%EC%A3%BC"
# req.urlopen(url)
# soup = BeautifulSoup(res,'html.parser')
url="https://ko.wikisource.org/wiki/%EC%A0%80%EC%9E%90:%EC%9C%A4%EB%8F%99%EC%A3%BC"
res=req.urlopen(url)
soup=BeautifulSoup(res, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="ko">
# <head>
# <meta charset="utf-8"/>
# <title>저자:윤동주 - 위키문헌, 우리 모두의 도서관</title>
# ...

# %%
res=soup.select("#mw-content-text > div.mw-parser-output > ul:nth-child(6) > li > b > a")
res
# Out:
# [<a href="/wiki/%ED%95%98%EB%8A%98%EA%B3%BC_%EB%B0%94%EB%9E%8C%EA%B3%BC_%EB%B3%84%EA%B3%BC_%EC%8B%9C" title="하늘과 바람과 별과 시">하늘과 바람과 별과 시</a>]

# %%
#res2=soup.select("#mw-content-text > div.mw-parser-output > ul:nth-child(6) > li")

#soup.select("#mw-content-text > div.mw-parser-output > ul:nth-child(6) > li > ")
p_list=soup.select("#mw-content-text > div.mw-parser-output > ul:nth-child(9) > li:nth-child(1) > a")
p_list
# len(p_list)
# for p in p_list:
#     title=p.string
#     print("=",title)
#mw-content-text > div.mw-parser-output > ul:nth-child(6) > li
#mw-content-text > div.mw-parser-output > ul:nth-child(6) > li > ul > li:nth-child(1) > a

#mw-content-text > div.mw-parser-output > ul:nth-child(6) > li > ul > li:nth-child(2) > a
# Out:
# []

# %%
url="https://music.bugs.co.kr/chart"
res=req.urlopen(url)
soup=BeautifulSoup(res,'html.parser')
res1=soup.select("#CHARTrealtime > table > tbody > tr:nth-child(1) > th > p > a")
res1
# Out:
# []
