# %%
import pandas as pd

# %%
aa=pd.read_csv('C:/Users/jinsu1/Downloads/output_dtg.txt', sep='|')
#aa.columns=["운수회사코드", "자동차등록번호", "운수회사 소재지코드", "자료제출일시"]
aa
# Out:
#                           HMC-EURO6DTGYR-200KA  KMJHG17G  16  \
# 5  196003 19121320244000                    30      1357   0
#           19121320244100                    29      1219   1
#           19121320244200                    27      1088   1
#           19121320244300                    25       996   0
#           19121320244400                    22       933   0
# ...                                        ...       ...  ..
# 13 196011 19121320425500                     6       652   1
#           19121320425600                     1       776   0
#           19121320425700                     0      1141   0
#           19121320425800                     0      1144   0
#           19121320425900                     2      1017   0
#
#                           d22100e174dadf9f1aa9bf296d4d32af36c1b03a5724a919198a1222367bfff5  \
# 5  196003 19121320244000                                          126805416
# ...
